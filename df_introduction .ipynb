# %%
import pandas as pd

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[4,27,28,33])

# %%
df
# Out:
#                                                        4   \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df.rename(columns = {4: 'name', 27: 'director', 28: 'activity', 33:'founders'}, inplace=True)

# %%
df
# Out:
#                                                      name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df['director'][210]
# Out:
# 'Иманкожоева Шайы Рахматовна'

# %%
df.loc[389:5678]
# Out:
#                                                    name  \
# 389   Общественное объединение "Бишкекский центр пси...
# 390   Общественный фонд "Благотворительный обществен...
# 391   АО закрытого типа " УРАН " (находится в процес...
# 392                                 ОсОО " КЫЗЫЛ-КАРА "
# 393   Управление внебюджетной деятельности Министерс...
# 394   Ошское представительство Фонд Развития сельско...
# 395        Обшественный Благотворительный фонд " НИЕТ "
# 396                                    ООО "БАЙТИК-ТУР"
# 397   ООО  Научно-производственное  объединение  " С...
# 398                                      ОсОО " ШАБАН "
# 399   Некоммерческая организация жилищно-строительны...
# 400   Объединение работодателей"Ассоциация содействи...
# 401                                      ОсОО " МГМ-А "
# 402                           Общественный фонд "Сахий"
# 403                                  ОсОО " V. Alisher"
# 404                            Учреждение"Бизнес-Центр"
# ...

# %%
df.loc[1:15]
# Out:
#                                                  name  \
# 1                                   ОО "Кайберен эне"
# 2   Общество с ограниченной ответственностью "Дете...
# 3              Иностранное Казахское ОсОО "Валькирия"
# 4                                      ОсОО "Harour''
# 5   Государственное предприятие "Иссык-кульское ры...
# 6                    ОсОО Редакция газеты " Эл созу "
# 7        РО "Церковь Евангельских христиан-баптистов"
# 8     Общество с ограниченной ответственностью "Вояж"
# 9         РО "Церковь Евангельских Христян-баптистов"
# 10  Общество с ограниченной ответственностью "Мана...
# 11  Совместное кыргызско-казахстанское общество с ...
# 12             Производственный кооператив "Кожешкен"
# 13           Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14       Южное отделение Национального агенства связи
# 15  Общество с ограниченной ответственностью "Жолб...
#
#                             director  \
# 1        Омурбеков Алмаз Ороскулович
# ...

# %%
df.loc[111110:]
# Out:
#                                                      name  \
# 111110  Общество с ограниченной ответственностью "Акса...
# 111111  Общество с ограниченной ответственностью "Микр...
# 111112  Общество с ограниченной ответственностью "Хан ...
# 111113  Общество с ограниченной ответственностью "Лого...
# 111114  Сельскохозяйственный производственный кооперат...
# 111115  Филиал Открытого акционерного общества "Россий...
# 111116   Общество с ограниченной ответственностью "Тулга"
# 111117  Общество с ограниченной ответственностью "Эйч ...
# 111118  Общество с ограниченной ответственностью "Техо...
# 111119  Общество с ограниченной ответственностью "Алан...
# 111120     Учреждение "Нарынский районный отдел культуры"
# 111121  Общество с ограниченной ответственностью "Фина...
# 111122  Общество с ограниченной ответственностью "Кырг...
# 111123  Общество с ограниченной ответственностью "Кырг...
# 111124           Общественное объединение "Доолотбек "К""
# ...

# %%
df.loc[389:5678],['activity']
# Out:
# (                                                   name  \
#  389   Общественное объединение "Бишкекский центр пси...
#  390   Общественный фонд "Благотворительный обществен...
#  391   АО закрытого типа " УРАН " (находится в процес...
#  392                                 ОсОО " КЫЗЫЛ-КАРА "
#  393   Управление внебюджетной деятельности Министерс...
#  394   Ошское представительство Фонд Развития сельско...
#  395        Обшественный Благотворительный фонд " НИЕТ "
#  396                                    ООО "БАЙТИК-ТУР"
#  397   ООО  Научно-производственное  объединение  " С...
#  398                                      ОсОО " ШАБАН "
#  399   Некоммерческая организация жилищно-строительны...
#  400   Объединение работодателей"Ассоциация содействи...
#  401                                      ОсОО " МГМ-А "
#  402                           Общественный фонд "Сахий"
#  403                                  ОсОО " V. Alisher"
# ...

# %%
df.loc[df['director']=='Омурбеков Алмаз Ороскулович'
# Out:
#   File "<ipython-input-145-c795f70932ed>", line 1
#     df.loc[df['director']=='Омурбеков Алмаз Ороскулович'
#                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
df.loc[(df['director']==df['founders'])],'director'
# Out:
# (                                                     name  \
#  2       Общество с ограниченной ответственностью "Дете...
#  3                  Иностранное Казахское ОсОО "Валькирия"
#  8         Общество с ограниченной ответственностью "Вояж"
#  10      Общество с ограниченной ответственностью "Мана...
#  15      Общество с ограниченной ответственностью "Жолб...
#  24      Общество с ограниченной ответственностью "КМ-С...
#  27         Общество с ограниченной ответственностью "Шох"
#  29      Общество с ограниченной ответственностью "Чынгыз"
#  30                                         ООО "АЛМАЗ RT"
#  31      Общество с ограниченной ответственностью "Адил...
#  35       Общество с ограниченной ответственностью "Кунан"
#  37        Учреждение "Центр национальных игр Мира-"МАНАС"
#  40      Акционерное общество закрытого типа "Юнион-Кон...
#  44                                     ОсОО "Лаачын-Ордо"
#  46                       ОсОО Редакция газеты "АНТИМАГИЯ"
# ...

# %%
def a_x_29(a):
    return a*2/100**2

# %%
a_x_29(3.98)
# Out:
# 0.000796

# %%
a=lambda x:x*2

# %%
a(4)
# Out:
# 8

# %%
df[df['director'].str.contains('Ринат')]
# Out:
#                                                      name  \
# 25      Совместное Кыргызско-Немецкое общество с огран...
# 503                         ООО парикмахерская " КАРИНА "
# 3893    Общество с оганиченной ответственностью "Росси...
# 4205    Общество с ограниченной ответственностью "Спец...
# 4356    Общество с ограниченной ответственностью  "БРВ...
# 5770    Общество с Ограниченной Ответственностью "GRAN...
# 6666    Общество с ограниченной ответственностью "Фарм...
# 8165    Общество с ограниченной ответственностью  "IQ"...
# 8525    Общество с ограниченной ответственностью "ADEN...
# 9533    Общество с ограниченной ответственнотью "Союз ...
# 9994    Общество с ограниченной ответственностью  "Фир...
# 10837                                       ООО "К-Булак"
# 11931   Общество с ограниченной ответственностью "Comp...
# 12550   Общество с ограниченной ответственностью "МАРА...
# 13051   Общество с ограниченной ответственностью "Саун...
# ...

# %%
df.fillna('',inplace=True)

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[16,17])

# %%
df
# Out:
#                          16             17
# 0                 ул.Ленина             43
# 1                  Дорожная             14
# 2               ул.Гагарина              2
# 3                Загородная              9
# 4                Лермантова             21
# 5                       NaN            NaN
# 6                    пр.Чуй           47-2
# 7              Серпуховская             98
# 8                  ул. Джим             3А
# 9             Комсомольская             19
# 10                      NaN              8
# 11                      NaN            9/1
# 12                      NaN            NaN
# 13             ул.Лесхозная             10
# 14          Курманжан-Датка           79-б
# 15           ул. Ферганская             82
# 16                      NaN            NaN
# 17                 Западная             86
# 18        Краснооктябрьская           60-2
# 19                    8-мкр          29-85
# 20                  Исанова         143-51
# ...

# %%
df.rename(columns = {16: 'adress'}, inplace=True)

# %%
df
# Out:
#                      adress             17
# 0                 ул.Ленина             43
# 1                  Дорожная             14
# 2               ул.Гагарина              2
# 3                Загородная              9
# 4                Лермантова             21
# 5                       NaN            NaN
# 6                    пр.Чуй           47-2
# 7              Серпуховская             98
# 8                  ул. Джим             3А
# 9             Комсомольская             19
# 10                      NaN              8
# 11                      NaN            9/1
# 12                      NaN            NaN
# 13             ул.Лесхозная             10
# 14          Курманжан-Датка           79-б
# 15           ул. Ферганская             82
# 16                      NaN            NaN
# 17                 Западная             86
# 18        Краснооктябрьская           60-2
# 19                    8-мкр          29-85
# 20                  Исанова         143-51
# ...

# %%
df[df['adress'].str.contains('Тоголок Молдо')]
# Out:
#                      adress            17
# 81            Тоголок Молдо             1
# 296           Тоголок Молдо            60
# 303           Тоголок Молдо            60
# 599       ул. Тоголок Молдо            60
# 754           Тоголок Молдо           1-а
# 1083          Тоголок Молдо            61
# 1231      ул. Тоголок Молдо            60
# 1285          Тоголок Молдо          81-а
# 1366          Тоголок Молдо            40
# 1472          Тоголок Молдо             1
# 1507      ул. Тоголок Молдо            56
# 1904      ул. Тоголок Молдо            60
# 2449      ул. Тоголок Молдо            73
# 2585      ул. Тоголок Молдо         21-33
# 2850      ул. Тоголок Молдо            60
# 2968       ул.Тоголок Молдо             3
# 2974          Тоголок Молдо            17
# 3026    улица Тоголок Молдо            60
# 3084      ул. Тоголок Молдо            19
# 3200          Тоголок Молдо            60
# 3781      ул. Тоголок Молдо         273 А
# ...

# %%
df.fillna('',inplace=True)

# %%
df
# Out:
#                      adress             17
# 0                 ул.Ленина             43
# 1                  Дорожная             14
# 2               ул.Гагарина              2
# 3                Загородная              9
# 4                Лермантова             21
# 5
# 6                    пр.Чуй           47-2
# 7              Серпуховская             98
# 8                  ул. Джим             3А
# 9             Комсомольская             19
# 10                                       8
# 11                                     9/1
# 12
# 13             ул.Лесхозная             10
# 14          Курманжан-Датка           79-б
# 15           ул. Ферганская             82
# 16
# 17                 Западная             86
# 18        Краснооктябрьская           60-2
# 19                    8-мкр          29-85
# 20                  Исанова         143-51
# 21                   Фучика          20-12
# 22               пос. Южный            б-н
# ...

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[33])

# %%
df
# Out:
#                                                        33
# 0       Замените на физическое лицо 1, Замените на физ...
# 1                                   инициаторы 10 человек
# 2                          Жансеркеев аманат Базарканович
# 3                             Бражников Сергей Алексеевич
# 4                             Абдылдаев Нурлан Кирешеевич
# 5       Департамент рыбного хозяйства Кыргызской Респу...
# 6                                 null, Калманбетов Баялы
# 7                         инициаторы по списку 10-человек
# 8                                          Каримов Руслан
# 9                         инициаторы по списку 10-человек
# 10                                         Шафиев Юлчувай
# 11      Общество с ограниченной ответственностью фирма...
# 12      Члены производственного кооператива 333-челове...
# 13      Бишкекское производственное предприятие городс...
# 14      Национальный агенство связи  Кыргызской Респуб...
# ...

# %%
df.rename(columns = {33:'founders'}, inplace=True)

# %%
df
# Out:
#                                                  founders
# 0       Замените на физическое лицо 1, Замените на физ...
# 1                                   инициаторы 10 человек
# 2                          Жансеркеев аманат Базарканович
# 3                             Бражников Сергей Алексеевич
# 4                             Абдылдаев Нурлан Кирешеевич
# 5       Департамент рыбного хозяйства Кыргызской Респу...
# 6                                 null, Калманбетов Баялы
# 7                         инициаторы по списку 10-человек
# 8                                          Каримов Руслан
# 9                         инициаторы по списку 10-человек
# 10                                         Шафиев Юлчувай
# 11      Общество с ограниченной ответственностью фирма...
# 12      Члены производственного кооператива 333-челове...
# 13      Бишкекское производственное предприятие городс...
# 14      Национальный агенство связи  Кыргызской Респуб...
# ...

# %%
df[df['founders'].str.contains('Тахмурас')]
# Out:
# Empty DataFrame
# Columns: [founders]
# Index: []

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[4])

# %%
df
# Out:
#                                                         4
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df.rename(columns = {4:'name'}, inplace=True)

# %%
df
# Out:
#                                                      name
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df[df['name'].str.contains('Чуриков')]
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
df.fillna('',inplace=True)

# %%
df
# Out:
#                                                      name
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[28])

# %%
df
# Out:
#                                                        28
# 0       Выращивание зерновых культур (кроме риса и гре...
# 1                                                     NaN
# 2        Обеспечение общественного порядка и безопасности
# 3                                                     NaN
# 4                                                     NaN
# 5                                Рыбоводство пресноводное
# 6                                                     NaN
# 7                                                     NaN
# 8                       Оптовая торговля  лесоматериалами
# 9                                                     NaN
# 10      Прочие строительно-монтажные работы, не включе...
# 11      Прочая деятельность по организации отдыха и ра...
# 12             Обработка риса и производство рисовой муки
# 13      Прочие строительно-монтажные работы, не включе...
# 14                                                    NaN
# ...

# %%
df.rename(columns = {28:'activity'}, inplace=True)

# %%
df
# Out:
#                                                  activity
# 0       Выращивание зерновых культур (кроме риса и гре...
# 1                                                     NaN
# 2        Обеспечение общественного порядка и безопасности
# 3                                                     NaN
# 4                                                     NaN
# 5                                Рыбоводство пресноводное
# 6                                                     NaN
# 7                                                     NaN
# 8                       Оптовая торговля  лесоматериалами
# 9                                                     NaN
# 10      Прочие строительно-монтажные работы, не включе...
# 11      Прочая деятельность по организации отдыха и ра...
# 12             Обработка риса и производство рисовой муки
# 13      Прочие строительно-монтажные работы, не включе...
# 14                                                    NaN
# ...

# %%
df[df['activity'].str.contains('Строительство')]
# Out:
#                                                  activity
# 317                  Строительство жилых и нежилых зданий
# 545                          Строительство железных дорог
# 564                  Строительство жилых и нежилых зданий
# 608                  Строительство жилых и нежилых зданий
# 675                  Строительство жилых и нежилых зданий
# 820                  Строительство жилых и нежилых зданий
# 864                  Строительство жилых и нежилых зданий
# 1015                 Строительство жилых и нежилых зданий
# 1265    Строительство прочих объектов гражданского наз...
# 1596    Строительство прочих объектов гражданского наз...
# 1878    Строительство прочих объектов гражданского наз...
# 1908    Строительство прочих объектов гражданского наз...
# 2006                 Строительство жилых и нежилых зданий
# 2125                         Строительство железных дорог
# 2203                 Строительство жилых и нежилых зданий
# ...

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[19])

# %%
df
# Out:
#                      19
# 0                   NaN
# 1                   NaN
# 2                 28419
# 3              27-32-34
# 4                   NaN
# 5                 42421
# 6              28-05-22
# 7              25-19-50
# 8                   NaN
# 9                   NaN
# 10        03222 7-17-13
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19             47-17-21
# 20             21-33-70
# 21                  NaN
# 22
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26             23-75-66
# 27                  NaN
# 28              2-18-63
# 29                  NaN
# ...                 ...
# 127588              NaN
# 127589           212562
# 127590              NaN
# 127591           680497
# 127592           213786
# 127593              NaN
# 127594              NaN
# ...

# %%
df.rename(columns = {19:'tel-numbers'}, inplace=True)

# %%
df
# Out:
#             tel-numbers
# 0                   NaN
# 1                   NaN
# 2                 28419
# 3              27-32-34
# 4                   NaN
# 5                 42421
# 6              28-05-22
# 7              25-19-50
# 8                   NaN
# 9                   NaN
# 10        03222 7-17-13
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19             47-17-21
# 20             21-33-70
# 21                  NaN
# 22
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26             23-75-66
# 27                  NaN
# 28              2-18-63
# 29                  NaN
# ...                 ...
# 127588              NaN
# 127589           212562
# 127590              NaN
# 127591           680497
# 127592           213786
# 127593              NaN
# 127594              NaN
# ...

# %%
df[df['tel-numbers'].str.contains('432')]
# Out:
#                    tel-numbers
# 544              432321,472800
# 833                     434327
# 880                     432402
# 1651                    432222
# 2893                    261432
# 2897                    432656
# 4233                0543218346
# 4321                0551243212
# 4452                0555243277
# 4602                0551243212
# 4704                0543239188
# 5091                0394432970
# 5539                     43290
# 6553               0777-443275
# 7069               0772-043200
# 7822                     27432
# 8695                0543249084
# 8723              0773 432-917
# 9711                0775984325
# 9749                    432731
# 9957                0543216170
# 10065                   432858
# 10073               0543236079
# 10601                    54321
# 10856               0543218288
# 11126               0394321253
# 12683                   432262
# 12869                   432775
# 15704                   432847
# ...

# %%
df.fillna('',inplace=True)

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[4,16,19,27,28,33])

# %%
df
# Out:
#                                                        4   \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df.rename(columns = {4:'name',
                     16:'adress', 
                     19: 'tel-numbers', 
                     27: 'director', 
                     28: 'activity', 
                     33:'founders'}, inplace=True)

# %%
df
# Out:
#                                                      name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...
